# %% [markdown]
# # AI-Run Hackathon Reproducibility Notebook
#
# This notebook demonstrates how to reproduce the ranking output using the repository files and Git LFS dataset.

# %% [markdown]
# ## Instructions
#
# 1. Run the shell cell below to install Git LFS (if needed) and pull the dataset.
#     - In Colab, use `!git lfs install && git lfs pull`.
# 2. Run the Python cell to execute the ranking pipeline.
# 3. Inspect `ui/ranking/outputs/submission.csv`.

# %%
# Shell command for Colab to install Git LFS and pull the dataset
# !apt-get update -qq && apt-get install -y -qq git-lfs
# !git lfs install
# !git lfs pull

# %%
# Run the ranking pipeline from the notebook context
import os
repo_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
print('Repository root:', repo_root)
os.chdir(repo_root)
# !python ui/rank.py

# %%
# List outputs to verify the generated submission
# !ls -l ui/ranking/outputs
# !head -n 5 ui/ranking/outputs/submission.csv
